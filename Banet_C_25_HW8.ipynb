# %% [markdown]
# ## Week 9 (Wed) - Plotting in Python

# %% [markdown]
# This project will introduce you to working with and plotting/respresenting data.
# (Written by P. Frinchaboy, M. Bovill, and J. Donor)

# %% [markdown]
# ### Plotting data is one of the easiest way to determine if something may be odd/wonrg with your data.
#
# Also visuallying data is a key way to help interpret things in science (__e.g., a picture is worth a thousand words, especially when your data is 100,000+ data points!__).

# %%
# Import the needed fuctions
from matplotlib import pyplot as plt 
#matplotlib.pyplot is the standard for making plots and is derived from Matlab
import numpy as np

# %% [markdown]
# ### Lets plot our data from last class!!!  YAY WE GET TO FINALLY MAKE PLOTS!

# %%
# READ IN DATA FILE/
data = np.genfromtxt("munich_temperatures_average_with_bad_data.txt")
Date = data[:,0]
Temp = data[:,1] 

# PLOT TO VERIFY FILE READ 
# This creates a figure object and sets the size
fig1 = plt.figure(figsize=(20,10))
# This allows subplots, for now this is set to 1 plot
ax1 = fig1.add_subplot(111)

ax1.scatter(Date,Temp,s=15,c='k',alpha=0.5)

# This increases the 
ax1.xaxis.set_tick_params(labelsize=20)
ax1.yaxis.set_tick_params(labelsize=20)

# %% [markdown]
# ## A new plot
#
# You will first need to download the plain text data file "CG20.dat", that we will read in to have data to plot.

# %%
# This will read in the data into a numpy array
data = np.genfromtxt("CG20.csv", delimiter=",")
# This will seperate specific columns of the data into newly created variables
AgeNN = data[:,14]  # Log Age 
DistPc = data[:,17] # Distance
XGC = data[:,18]   # X-coordinate
YGC = data[:,19]   # Y-coordinate
ZGC = data[:,20]   # Z-coordinate
RGC = data[:,21]   # Radius-coordinate

# %% [markdown]
# __Next will will gerenerate a first plot of X vs Y position.__
#
# This will introduce the first options you will have.

# %%
# Creating a scatter plot in log log space using an object oriented approach
fig = plt.figure()                           # makes a figure
ax = fig.add_subplot(111)                    # make a 1,1,1 (single) figure
ax.scatter(XGC,YGC,s=5,c='k',alpha=0.3)      # makes a scatter plot (s = size, c = color, alpha = transparency)

# %%
# Changing the size of the plot -- figsize
fig = plt.figure(figsize=(16,10))          # makes a figure (allow us to change the size of the figure)
ax = fig.add_subplot(111)                  # make a 1,1,1 (single) figure
ax.scatter(XGC,YGC,s=5,c='k',alpha=0.3)    # makes a scatter plot (s = size, c = color, alpha = transparency)

# %% [markdown]
# Well this looks like a nice plot, but if you gave this to someone could they tell what it was a plot of?
#
# We need add labels to inform the reader, also we will limit the plot to only show a portion of the data.

# %%
# Reread the data to get ALL of the columns
data = np.genfromtxt("CG20.csv", delimiter=",", names = True)

print(data.dtype.names)
# this is the same as above
fig = plt.figure(figsize=(16,10))
ax = fig.add_subplot(111)
ax.scatter(data['X'],data['Y'],s=20,c='k',alpha=0.3)    # makes a scatter plot (s = size, c = color, alpha = transparency)


# Now, we will label the axis and set the limits of the axis and increase ticksize of the axis
# Set the start and end of range you want to display on the x and yaxis 
ax.set_xlim(-2000,2000)
ax.set_ylim(-1500,1500)

# add the labels
ax.set_xlabel("$X_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating
ax.set_ylabel("$Y_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating

# increase the size of the numbers on the axes
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
# Out:
# ('Cluster', 'RAdeg', 'DEdeg', 'GLON', 'GLAT', 'r50', 'nbstars07', 'pmRA', 'e_pmRA', 'pmDE', 'e_pmDE', 'plx', 'e_plx', 'Flag', 'AgeNN', 'AVNN', 'DMNN', 'DistPc', 'X', 'Y', 'Z', 'Rgc')

# %%
# this is the same as above
fig = plt.figure(figsize=(8,5)) #scales the point size 
ax = fig.add_subplot(111)

# Sizing the points according to a 3rd attribute - rvir
ax.scatter(data['X'],data['Y'],s=200*data['r50'],c='k',alpha=0.3) #scaling s = 200 * data['r50'] scales the SIZE of the dots on plot

# Now, we will label the axis and set the limits of the axis and increase ticksize of the axis
# Set the start and end of range you want to display on the x and yaxis 
ax.set_xlim(-2000,2000)
ax.set_ylim(-1500,1500)

# add the labels
ax.set_xlabel("$X_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating
ax.set_ylabel("$Y_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating

# increase the size of the numbers on the axes
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)

# %%
# this is the same as above
fig = plt.figure(figsize=(16,10))
ax = fig.add_subplot(111)

# Coloring the points by a 4th attribute and adding a color bar
image = ax.scatter(data['X'],data['Y'],s=200*data['r50'],c=data['AgeNN'],edgecolor='k',cmap="viridis",alpha=0.5) #c = COLOR coding edgecolor 'k' = black, cmap = color map
#"viridis" goes purple to green which is color blind friendly, also, cool, plasma, rainbow, etc. many different color maps
bar = fig.colorbar(image,orientation="vertical",pad=0.01) #adds the color bar on the r-hand side
bar.set_label('$log_{10} (Age)$',size=15)


# Now, we will label the axis and set the limits of the axis and increase ticksize of the axis
# Set the start and end of range you want to display on the x and yaxis 
ax.set_xlim(-2000,2000)
ax.set_ylim(-1500,1500)

# add the labels
ax.set_xlabel("$X_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating
ax.set_ylabel("$Y_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating

# increase the size of the numbers on the axes
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)

# %%
# this is the same as above
fig = plt.figure(figsize=(16,10))
ax = fig.add_subplot(111)

# Coloring the points by a 4th attribute and adding a color bar
image = ax.scatter(data['X'],data['Y'],s=200*data['r50'],c=data['AgeNN'],edgecolor='k',cmap="viridis",alpha=0.5)
bar = fig.colorbar(image,orientation="vertical",pad=0.01)
bar.set_label('$log_{10} (Age)$',size=15)


# Now, we will label the axis and set the limits of the axis and increase ticksize of the axis
# Set the start and end of range you want to display on the x and yaxis 
ax.set_xlim(-2000,2000)
ax.set_ylim(-1500,1500)

# add the labels
ax.set_xlabel("$X_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating
ax.set_ylabel("$Y_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating

# NOW WE CAN ADD TEXT!!
ax.text(-1300, 1200, "Text is Awesome!",size=20)
ax.text(10, -1300, "And you can put it anywhere!",size=30) #adds text, add the x, y coordinate where to put the text, then write the text

# increase the size of the numbers on the axes
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)

# %%
# this is the same as above
fig = plt.figure(figsize=(16,10))
ax = fig.add_subplot(111)

# Coloring the points by a 4th attribute and adding a color bar
image = ax.scatter(data['X'],data['Y'],s=200*data['r50'],c=data['AgeNN'],edgecolor='k',cmap="viridis",alpha=0.5)
bar = fig.colorbar(image,orientation="vertical",pad=0.01)
bar.set_label('$log_{10} (Age)$',size=15)

ax.text(100, -340, "You can also insert subplots!",size=30)

# Inserting a subplot, make a histogram!!
ax_sub = fig.add_axes([0.5,0.2,0.2,0.2]) #where it's centered and how big it is
ax_sub.hist(data['nbstars07'],bins=np.logspace(0,3,20),log='True')#can use a logspace or linspace, starting at 0 to 3 with 20 subdivisions (20 bins) which are the bars
ax_sub.set_xscale('log')
ax_sub.set_xlabel('Stars',size=20)
ax_sub.set_ylabel('N',size=20)

ax.set_xlim(-2000,2000)
ax.set_ylim(-1500,1500)

ax.set_xlabel("$X_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating
ax.set_ylabel("$Y_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating

# increase the size of the numbers on the axes
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
ax_sub.xaxis.set_tick_params(labelsize=20)
ax_sub.yaxis.set_tick_params(labelsize=20)

# %%
# Adding multiple plots
fig = plt.figure(figsize=(16,10))

ax1 = fig.add_subplot(221)
ax1.scatter(data['X'],data['Y'])

ax2 = fig.add_subplot(222)
ax2.scatter(data['Y'],data['Z'])

ax3 = fig.add_subplot(223)
ax3.scatter(data['X'],data['Z'])

ax4 = fig.add_subplot(224)
ax4.scatter(data['Rgc'],data['Z'])

# %%
fig = plt.figure(figsize=(16,10))

# Condensing the plots
fig.subplots_adjust(hspace=0.0, wspace=0.0)


ax1 = fig.add_subplot(221)
ax1.scatter(data['X'],data['Y'])

ax2 = fig.add_subplot(222)
ax2.scatter(data['Y'],data['Z'])

ax3 = fig.add_subplot(223)
ax3.scatter(data['X'],data['Z'])

ax4 = fig.add_subplot(224)
ax4.scatter(data['Rgc'],data['Z'])

# Removing unneeded tick axis
ax1.set_xticks([])
ax2.set_yticks([])
ax2.set_xticks([])
ax4.set_yticks([])

# AND CAN SAVE YOUR FIGURES  (jpeg, pdf)!   
plt.savefig("CG20_tmp.jpeg")

# %% [markdown]
# ## Exercise 1
#
# Now a plot with RAdeg vs. DEdeg with size scaled by r50 and color coded by the log10 of nbstars07.  Note make it as readable as possible!

# %%
# this is the same as above
fig = plt.figure(figsize=(16,10))
ax = fig.add_subplot(111)

# Coloring the points by a 4th attribute and adding a color bar
image = ax.scatter(data['RAdeg'],data['DEdeg'],s=1000*data['r50'],c=data['nbstars07'],edgecolor='k',cmap="viridis",alpha=0.5) #c = COLOR coding edgecolor 'k' = black, cmap = color map
#"viridis" goes purple to green which is color blind friendly, also, cool, plasma, rainbow, etc. many different color maps
bar = fig.colorbar(image,orientation="vertical",pad=0.01) #adds the color bar on the r-hand side
bar.set_label('$log_{10} (Number of Stars)$',size=15)


# Now, we will label the axis and set the limits of the axis and increase ticksize of the axis
# Set the start and end of range you want to display on the x and yaxis 
ax.set_xlim(-5,400)
ax.set_ylim(-100,100)

# add the labels
ax.set_xlabel("$X_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating
ax.set_ylabel("$Y_{GC}$ $(pc)$",size=20)   # allows LaTeX style formating

# increase the size of the numbers on the axes
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)

# %% [markdown]
# ### Exercise 2
#
# Panel 1) GLON vs. GLAT
#
# Panel 2) pmRA* vs pmDE
#
# Panel 3) Rgc vs. Z
#
# panel 4) AgeNN vs. DistPc
#
# Give the sizes of the points by 'r50' and color the points by AgeNN.
#
# **Make sure to label ALL your axis and include a colorbar.**<br>

# %%
fig = plt.figure(figsize=(16,10))

# Condensing the plots
#fig.subplots_adjust(hspace=0.0, wspace=0.0)


ax1 = fig.add_subplot(221)
image1 = ax1.scatter(data['GLON'],data['GLAT'],s=200*data['r50'],c=data['AgeNN'],edgecolor='k',cmap="viridis",alpha=0.5)
ax1.set_xlabel("$GLON$ $(deg)$",size=20)   # allows LaTeX style formating
ax1.set_ylabel("$GLAT$ $(deg)$",size=20)   # allows LaTeX style formating
bar = fig.colorbar(image1,orientation="vertical",pad=0.01) #adds the color bar on the r-hand side
bar.set_label('Age',size=15)



ax2 = fig.add_subplot(222)
image2 = ax2.scatter(data['pmRA'],data['pmDE'],s=200*data['r50'],c=data['AgeNN'],edgecolor='k',cmap="viridis",alpha=0.5)
ax2.set_xlabel("$RA$",size=20)   # allows LaTeX style formating
ax2.set_ylabel("$DE$",size=20)   # allows LaTeX style formating
bar = fig.colorbar(image2,orientation="vertical",pad=0.01) #adds the color bar on the r-hand side
bar.set_label('Age',size=15)


ax3 = fig.add_subplot(223)
image3 = ax3.scatter(data['Rgc'],data['Z'],s=200*data['r50'],c=data['AgeNN'],edgecolor='k',cmap="viridis",alpha=0.5)
ax3.set_xlabel("$Rgc$",size=20)   # allows LaTeX style formating
ax3.set_ylabel("$Z$",size=20)   # allows LaTeX style formating
bar = fig.colorbar(image3,orientation="vertical",pad=0.01) #adds the color bar on the r-hand side
bar.set_label('Age',size=15)

ax4 = fig.add_subplot(224)
image4 = ax4.scatter(data['AgeNN'],data['DistPc'],s=200*data['r50'],c=data['AgeNN'],edgecolor='k',cmap="viridis",alpha=0.5)
ax4.set_xlabel("$Age$",size=20)   # allows LaTeX style formating
ax4.set_ylabel("$Dist$ $(Pc)$",size=20)   # allows LaTeX style formating
bar = fig.colorbar(image4,orientation="vertical",pad=0.01) #adds the color bar on the r-hand side
bar.set_label('Age',size=15)




# AND CAN SAVE YOUR FIGURES  (jpeg, pdf)!   
plt.savefig("HW_8mlp.jpeg")

# %% [markdown]
# ## HW 8 - Turn in this completed Notebook!
